# %%
# Dependencies
import pandas as pd
from pathlib import Path

# %%
# File To Load
planet_data_to_load = Path("PS_2025.01.27_19.02.15.csv")

# Read Data
planetData = pd.read_csv(planet_data_to_load, skiprows=293)

# Display First Few Rows
planetData.head()
# Out:
# C:\Users\greyw\AppData\Local\Temp\ipykernel_12848\143204655.py:5: DtypeWarning: Columns (4,5) have mixed types. Specify dtype option on import or set low_memory=False.
#   planetData = pd.read_csv(planet_data_to_load, skiprows=293)
#    rowid   pl_name hostname pl_letter    hd_name   hip_name         tic_id  \
# 0      1  11 Com b   11 Com         b  HD 107383  HIP 60202   TIC 72437047
# 1      2  11 Com b   11 Com         b  HD 107383  HIP 60202   TIC 72437047
# 2      3  11 Com b   11 Com         b  HD 107383  HIP 60202   TIC 72437047
# 3      4  11 UMi b   11 UMi         b  HD 136726  HIP 74793  TIC 230061010
# 4      5  11 UMi b   11 UMi         b  HD 136726  HIP 74793  TIC 230061010
#
#                         gaia_id  default_flag  sy_snum  ...   rowupdate  \
# 0  Gaia DR2 3946945413106333696             0        2  ...  2014-05-14
# 1  Gaia DR2 3946945413106333696             0        2  ...  2014-07-23
# 2  Gaia DR2 3946945413106333696             1        2  ...  2023-09-19
# ...
